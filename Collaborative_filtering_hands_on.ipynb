# %% [markdown]
# <a href="https://colab.research.google.com/github/AngeloKItio/AngeloKItio.github.io/blob/dev/Collaborative_filtering_hands_on.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
